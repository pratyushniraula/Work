# %%
#recommender systems:

#3 categories:
#1. Content-based filtering
    #profile for each user and item
        #need extra information about users and items
        #not scalable
#2. Collaborative filtering
    #dies not require profiles to be created
    #looks at previous ratings of the user

    #user - user similarity (based on ratings)
    #item - item similarity (based on ratings)

    #finding similar users: (A and B are sets)
    #    jaccard similarity measure: J(A, B) = |A ∩ B| / |A ∪ B|
            #problem: it does not take into acount the rating values
    #    cosine similarity measure: cos(θ) = (A · B) / (||A|| ||B||)
            #problem: treats missing values as "negative"
    #    pearson correlation coefficient: r = Σ((xi - x̄)(yi - ȳ)) / (sqrt(Σ(xi - x̄)²) * sqrt(Σ(yi - ȳ)²))
