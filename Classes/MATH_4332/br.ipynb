# %%
import tensorflow as tf

conv = tf.keras.layers.Conv2D(8, (3,3), input_shape=(64, 64, 3))
conv.build((None, 64, 64, 3))
print(conv.count_params())
# Out:
# 224
# /Users/pratyushniraula/Documents/Work/Classes/MATH_4332/.venv/lib/python3.13/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
