# %%
import random
#modulo

random.randint(1,10)

#floor division
#abs
#round
#pow
#min
#max
#sum
#eval
#bin
bin(10)
# Out:
# '0b1010'

# %%
#generate and print 25 random integress between 7 and 11
for i in range(25):
    print(random.randint(7,11))

print(25*'-')

#generate random integer x between 2 and 40, a random integer y between 3 and 7 and compute (x^y)
x = random.randint(2,40)
y = random.randint(3,7)
print((x**y))

print(25*'-')

#write a program that generates a random number between 1 and 7 and print your name that many times
name = "Pratyush Niraula"
z = random.randint(1,7)
for i in range(z):
    print(name)

print(25*'-')
#write a program that generates a random decimal number between 1 and 10 with two decimal places of accuracy
a = random.uniform(1,10)
print(round(a,2))

print(25*'-')
#write a program that generates 40 random numbers between 1 and 2, the second is between 1 and 3, the third is between 1 and 4, and so on up to 1 to 41.
for i in range(1,41):
    print(random.randint(1,i+1))

print(25*'-')
#write a program that asks the user for an integer representing the number of minutes and outputs the period of time in days, hours, and minutes
minutes = int(input("Enter the number of minutes: "))
days = minutes // 1440
hours = (minutes % 1440) // 60
mins = (minutes % 1440) % 60
print(minutes, " minutes is ", days, " days, ", hours, " hours, and ", mins, " minutes.", sep='')

print(25*'-')
#write a program that asks user for to enter 2 numbers x and y and compute abs(x-y)/(x+y)
x = float(input("Enter first number: "))
y = float(input("Enter second number: "))
result = abs(x-y)/(x+y)
print("The result is ", round(result,3), ".", sep='')

#write a program that asks the user to enter a power. Then find the last digit of 2 raised to that power.
power = int(input("Enter a power: "))
last_digit = (2**power) % 10
print("The last digit of 2 raised to the power ", power, " is ", last_digit, ".", sep='')

#write a program that asks the user to enter a power. Then find the last 2 digits of 2 raised to that power.
power = int(input("Enter a power: "))
last_two_digits = (2**power) % 100
print("The last two digits of 2 raised to the power ", power, " is ", last_two_digits, ".", sep='')

#write a program that prints out the sine and cosine of the angles ranging from 0 to 360 degrees in increments of 15 degrees. Each result should be rounded to 4 decimal places.
import math
for angle in range(0, 361, 15):
    sine = round(math.sin(math.radians(angle)), 4)
    cosine = round(math.cos(math.radians(angle)), 4)
    print("Angle: ", angle, " degrees -> Sine: ", sine, ", Cosine: ", cosine, sep='')
# Out:
# 11
# 8
# 8
# 11
# 7
# 10
# 7
# 11
# 10
# 9
# 9
# 7
# 8
# 9
# 7
# 9
# 11
# 8
# 10
# 7
# 9
# 9
# 9
# 7
# 7
# -------------------------
# 42618442977
# -------------------------
# Pratyush Niraula
# -------------------------
# 2.85
# -------------------------
# 1
# 1
# 4
# 1
# 6
# 4
# 5
# 1
# 2
# 10
# 8
# 11
# 10
# 14
# 2
# 6
# 16
# 4
# 2
# 20
# 5
# 5
# 2
# 12
# 11
# 11
# 14
# 28
# 16
# 26
# 24
# 17
# 6
# 21
# 3
# 32
# 9
# 18
# 33
# 6
# -------------------------
# 10000 minutes is 6 days, 22 hours, and 40 minutes.
# -------------------------
# The result is 0.613.
# The last digit of 2 raised to the power 3 is 8.
# The last two digits of 2 raised to the power 5 is 32.
# Angle: 0 degrees -> Sine: 0.0, Cosine: 1.0
# Angle: 15 degrees -> Sine: 0.2588, Cosine: 0.9659
# Angle: 30 degrees -> Sine: 0.5, Cosine: 0.866
# Angle: 45 degrees -> Sine: 0.7071, Cosine: 0.7071
# Angle: 60 degrees -> Sine: 0.866, Cosine: 0.5
# Angle: 75 degrees -> Sine: 0.9659, Cosine: 0.2588
# ...
