# %%
print(11*'*')
print(11*'*')
print(11*'*')
print(11*'*')
# Out:
# ***********
# ***********
# ***********
# ***********

# %%
print(11*'*')
print('*', ' '*7, '*')
print('*', ' '*7, '*')
print(11*'*')
# Out:
# ***********
# *         *
# *         *
# ***********

# %%
print('*')
print('**')
print('***')
print('****')
# Out:
# *
# **
# ***
# ****

# %%
print(float((512-282)/(47*48+5)))
# Out:
# 0.1017249004865104

# %%
x = int(input("Enter a number: "))
print("the square of ", x, " is ", x**2, ".", sep='')
# Out:
# the square of 12 is 144.

# %%
x = int(input("entet a number: "))
print(x, x*2, x*3, x*4, sep='---')
# Out:
# 12---24---36---48
