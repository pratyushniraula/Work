# %%
import pandas as pd
import numpy as np
from pathlib import Path
url = "https://raw.githubusercontent.com/JamesAmato/recitation/main/automobile/imports-85.data"
DATA_PATH = Path("imports-85.data")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 from pathlib import Path
#
# File ~/Documents/Work/Classes/CS_4375/.venv/lib/python3.13/site-packages/pandas/__init__.py:139
#     121 from pandas.core.reshape.api import (
#     122     concat,
#     123     lreshape,
#    (...)    135     qcut,
#     136 )
#     138 from pandas import api, arrays, errors, io, plotting, tseries
# --> 139 from pandas import testing
#     140 from pandas.util._print_versions import show_versions
#     142 from pandas.io.api import (
#     143     # excel
#     144     ExcelFile,
#    (...)    172     read_spss,
#     173 )
#
# File ~/Documents/Work/Classes/CS_4375/.venv/lib/python3.13/site-packages/pandas/testing.py:6
#       1 """
#       2 Public testing utility functions.
#       3 """
# ----> 6 from pandas._testing import (
#       7     assert_extension_array_equal,
#       8     assert_frame_equal,
#       9     assert_index_equal,
#      10     assert_series_equal,
#      11 )
#      13 __all__ = [
#      14     "assert_extension_array_equal",
#      15     "assert_frame_equal",
#      16     "assert_series_equal",
#      17     "assert_index_equal",
#      18 ]
#
# File ~/Documents/Work/Classes/CS_4375/.venv/lib/python3.13/site-packages/pandas/_testing/__init__.py:405
#     400     import pytest
#     402     return pytest.raises(expected_exception, match=None)
# --> 405 cython_table = pd.core.common._cython_table.items()
#     408 def get_cython_table_params(ndframe, func_names_and_expected):
#     409     """
#     410     Combine frame, functions from com._cython_table
#     411     keys and expected result.
#    (...)    423         List of three items (DataFrame, function, expected result)
#     424     """
#
# AttributeError: partially initialized module 'pandas' from '/Users/pratyushniraula/Documents/Work/Classes/CS_4375/.venv/lib/python3.13/site-packages/pandas/__init__.py' has no attribute 'core' (most likely due to a circular import)

# %%
df = pd.read_csv(DATA_PATH, header=None)
df.head()

#plot regression line
import matplotlib.pyplot as plt
plt.scatter(df[0], df[1])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       4 df = pd.read_csv(DATA_PATH, header=None)
#
# File ~/Documents/Work/Classes/CS_4375/.venv/lib/python3.13/site-packages/pandas/__init__.py:139
#     121 from pandas.core.reshape.api import (
#     122     concat,
#     123     lreshape,
#    (...)    135     qcut,
#     136 )
#     138 from pandas import api, arrays, errors, io, plotting, tseries
# --> 139 from pandas import testing
#     140 from pandas.util._print_versions import show_versions
#     142 from pandas.io.api import (
#     143     # excel
#     144     ExcelFile,
#    (...)    172     read_spss,
#     173 )
#
# File ~/Documents/Work/Classes/CS_4375/.venv/lib/python3.13/site-packages/pandas/testing.py:6
#       1 """
#       2 Public testing utility functions.
#       3 """
# ----> 6 from pandas._testing import (
#       7     assert_extension_array_equal,
#       8     assert_frame_equal,
#       9     assert_index_equal,
#      10     assert_series_equal,
#      11 )
#      13 __all__ = [
#      14     "assert_extension_array_equal",
#      15     "assert_frame_equal",
#      16     "assert_series_equal",
#      17     "assert_index_equal",
#      18 ]
#
# File ~/Documents/Work/Classes/CS_4375/.venv/lib/python3.13/site-packages/pandas/_testing/__init__.py:405
#     400     import pytest
#     402     return pytest.raises(expected_exception, match=None)
# --> 405 cython_table = pd.core.common._cython_table.items()
#     408 def get_cython_table_params(ndframe, func_names_and_expected):
#     409     """
#     410     Combine frame, functions from com._cython_table
#     411     keys and expected result.
#    (...)    423         List of three items (DataFrame, function, expected result)
#     424     """
#
# AttributeError: partially initialized module 'pandas' from '/Users/pratyushniraula/Documents/Work/Classes/CS_4375/.venv/lib/python3.13/site-packages/pandas/__init__.py' has no attribute 'core' (most likely due to a circular import)
