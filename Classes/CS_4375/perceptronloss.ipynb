# %%
#create a perceptron loss example
#!/usr/bin/env python3

import transformers
import torch
import argparse
from transformers import AutoTokenizer, AutoModelForCausalLM
import datasets
# Out:
# usage: ipykernel_launcher.py [-h] [--model_name MODEL_NAME]
#                              [--input_text INPUT_TEXT]
#                              [--max_length MAX_LENGTH]
#                              [--temperature TEMPERATURE] [--top_k TOP_K]
#                              [--top_p TOP_P]
# ipykernel_launcher.py: error: unrecognized arguments: --f=/Users/pratyushniraula/Library/Jupyter/runtime/kernel-v33845e9599a03c1e7e02ab2bd2efe7159db229f11.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# /Users/pratyushniraula/Library/Python/3.11/lib/python/site-packages/IPython/core/interactiveshell.py:3516: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
